# %% [markdown]
# # Book summaries - EDA and data cleaning
#
# The data used in this notebook was downloaded from: https://www.kaggle.com/applecrazy/cmu-book-summary-dataset

# %%
import pandas as pd
import csv
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import json
from collections import defaultdict

# %%
file_name = "./data/booksummaries/booksummaries.txt"

# %%
wiki_ids = []
freebase_ids = []
titles = []
authors = []
pub_dates = []
genres = []
summaries = []

genre_id_lookup = dict()
genre_to_book_dict = defaultdict(list)
book_to_genre_dict = defaultdict(list)
book_title_dict = dict()
# book_author_dict = dict()
book_summary_dict = dict()

with open(file_name, encoding = 'utf8') as f:
    reader = csv.reader(f, delimiter = "\t")
    for row in reader:
        wiki_ids.append(row[0])
        freebase_ids.append(row[1])
        titles.append(row[2])
        authors.append(row[3])
        pub_dates.append(row[4])
        genres.append(row[5])
        summaries.append(row[6])
        
        book_title_dict[row[0]] = row[2]
        book_summary_dict[int(row[0])] = row[6]
        
        try:
            genre_json = json.loads(row[5])
        except:
            if row[5] != "":
                print(row[0])
                print(row[5])
                break
                
        genre_id_lookup.update(genre_json)
        book_to_genre_dict[row[0]] = list(genre_json.keys())
        for genre_id in genre_json.keys():
            genre_to_book_dict[genre_id].append(row[0])

# %%
for book_id in genre_to_book_dict['/m/03qfd']:
    print(book_id, book_title_dict[book_id])
# Out:
# 29798 The Lord of the Rings
# 42572 The Eye of the World
# 606612 Eragon
# 697395 Wizard's First Rule
# 711958 Eldest
# 808425 The Sword of Shannara
# 811486 The Elfstones of Shannara
# 816343 First King of Shannara
# 963677 The Pillars of Creation
# 1086476 Stone of Tears
# 1193982 Naked Empire
# 1194749 Blood of the Fold
# 1194751 Temple of the Winds
# 1194752 Soul of the Fire
# 1466910 The Diary of a Young Girl
# 1483723 Chainfire
# 1484249 Aghwee the Sky Monster
# 1908763 Faith of the Fallen
# 1920495 Drowned Ammet
# 2015899 Dragon Rider
# 2095956 Phantom
# 2133376 Debt of Bones
# 2581528 The Shadow of the Torturer
# 2581531 The Claw of the Conciliator
# 2998715 Brisingr
# 3048166 The Merlin Conspiracy
# 3678706 Dark Lord of Derkholm
# 4117720 The Deed of Paksenarrion
# 5128402 Curse of the Mistwraith
# 5131160 The Tumbled House
# 5142729 Stormed Fortress
# 5667292 The Black Company
# 5667338 Shadows Linger
# 5667392 The White Rose
# 5667438 The Silver Spike
# 5667535 Shadow Games
# 5667675 Bleak Seasons
# 5667777 Water Sleeps
# 5667805 Soldiers Live
# 5670379 Till Death Do Us Part
# 5776519 The Sum of All Men
# 5776752 Brotherhood of the Wolf
# 5779726 Wizardborn
# 5779847 The Lair of Bones
# 5927277 Green Rider
# 5983051 First Rider's Call
# 5983624 The Mystery Of Holly Lane
# 7049805 The Children of Húrin
# 7157210 Furies of Calderon
# 7418400 Dark Wraith of Shannara
# 7769597 Hawk of May
# 7769640 Kingdom of Summer
# 7769658 In Winter's Shadow
# 8179123 Sons of the Oak
# 9729176 Confessor
# 9918426 The Game
# 14233619 The Sky Village
# 15162686 Darkwalker on Moonshae
# 15773551 The Last Ringbearer
# 16088871 Queen of Demons
# 17254822 The High King's Tomb
# 17400877 Worldbinder
# 17402867 Let Freedom Ring: Winning the War of Liberty over Liberalism
# 17836724 Academ's Fury
# 17836802 Captain's Fury
# 19573390 Master of Whitestorm
# 19577021 Drottningens juvelsmycke
# 23871057 Servant of the Dragon
# 23986473 The Magicians
# 24957772 The Way of Kings
# 25913453 Bones of the Dragon
# 25917587 The Palace of Illusions: A Novel
# 25919030 The Story of Sigurd the Volsung and the Fall of the Niblungs
# 25919213 Death by a Thousand Cuts
# 32691672 The Magician King
# 32710403 Sitti Nurbaya
# 32718518 In Praise of Idleness and Other Essays

# %%
book_data = pd.DataFrame(list(zip(wiki_ids, freebase_ids, titles, authors, pub_dates, genres, summaries)),
            columns = ["wiki_id","freebase_id","title","author","pub_date","genres","summaries"])

# %%
book_data.head()
# Out:
#   wiki_id freebase_id                                      title  \
# 0     620     /m/0hhy                                Animal Farm
# 1     843     /m/0k36                         A Clockwork Orange
# 2     986     /m/0ldx                                 The Plague
# 3    1756     /m/0sww  An Enquiry Concerning Human Understanding
# 4    2080     /m/0wkt                       A Fire Upon the Deep
#
#             author    pub_date  \
# 0    George Orwell  1945-08-17
# 1  Anthony Burgess        1962
# 2     Albert Camus        1947
# 3       David Hume
# 4     Vernor Vinge
#
#                                               genres  \
# 0  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3
# 4  {"/m/03lrw": "Hard science fiction", "/m/06n90...
#
#                                            summaries
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...
# 3   The argument of the Enquiry proceeds by a ser...
# 4   The novel posits that space around the Milky ...

# %%
## Does each book have a unique wiki_id?
len(book_data) == len(book_data['wiki_id'].unique())
# Out:
# True

# %%
## Does each book have a unique freebase_id?
len(book_data) == len(book_data['freebase_id'].unique())
# Out:
# True

# %%
## Does each book have a unique author?
len(book_data) == len(book_data['author'].unique())
# Out:
# False

# %%
## Which authors have the most books?
book_data.groupby('author')['wiki_id'].count().sort_values(ascending = False)
# Out:
# author
#                        2382
# Agatha Christie          74
# Franklin W. Dixon        68
# K. A. Applegate          62
# Stephen King             60
#                        ...
# Lillian Hellman           1
# Lilias MacBean Hart       1
# Liaquat Ahamed            1
# Li Zhisui                 1
# John de Lancie            1
# Name: wiki_id, Length: 4715, dtype: int64

# %%
## Which genres have the most books?
genre_counts = pd.DataFrame.from_dict({genre_id_lookup[k]:len(v) for k,v in genre_to_book_dict.items()}, 
                                      orient = "index",
                                     columns = ["count"])
genre_counts.sort_values(by = "count", ascending = False).head(20)
# Out:
#                         count
# Fiction                  5837
# Speculative fiction      5255
# Science Fiction          3575
# Novel                    3218
# Fantasy                  3080
# Children's literature    2647
# Young adult literature   1118
# Crime Fiction             948
# Suspense                  898
# Historical novel          850
# Thriller                  725
# Horror                    619
# Romance novel             537
# Historical fiction        475
# Detective fiction         428
# Adventure novel           417
# Non-fiction               322
# Alternate history         297
# Spy fiction               225
# Comedy                    170

# %%
## Need to transform book publication dates strings to dates
## There are 4 kinds of date strings shown here
missing_idx = book_data['pub_date'] == ""
year_only_idx = book_data['pub_date'].str.match(r'(^\d{4}$)') == True
ymd_idx = book_data['pub_date'].str.match(r'(^\d{4}-\d{2}-\d{2}$)') == True
year_month_idx = book_data['pub_date'].str.match(r'(^\d{4}-\d{2}$)') == True

# %%
# book_data['pub_date_cleaned'] = None

# %%
book_data[ymd_idx].head()
# Out:
#    wiki_id freebase_id                              title  \
# 0      620     /m/0hhy                        Animal Farm
# 5     2152     /m/0x5g     All Quiet on the Western Front
# 8     4081    /m/01b4w    Blade Runner 3: Replicant Night
# 9     4082    /m/01b56  Blade Runner 2: The Edge of Human
# 39   12653    /m/03b1x                God Emperor of Dune
#
#                   author    pub_date  \
# 0          George Orwell  1945-08-17
# 5   Erich Maria Remarque  1929-01-29
# 8            K. W. Jeter  1996-10-01
# 9            K. W. Jeter  1995-10-01
# 39         Frank Herbert  1981-05-28
#
#                                                genres  \
# 0   {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 5   {"/m/098tmk": "War novel", "/m/016lj8": "Roman...
# 8   {"/m/06n90": "Science Fiction", "/m/014dfn": "...
# 9   {"/m/06n90": "Science Fiction", "/m/014dfn": "...
# 39  {"/m/06n90": "Science Fiction", "/m/014dfn": "...
#
#                                             summaries     pub_date_cleaned
# 0    Old Major, the old boar on the Manor Farm, ca...  1945-08-17 00:00:00
# 5    The book tells the story of Paul Bäumer, a Ge...  1929-01-29 00:00:00
# 8    Living on Mars, Deckard is acting as a consul...  1996-10-01 00:00:00
# 9    Beginning several months after the events in ...  1995-10-01 00:00:00
# 39   The seemingly immortal God Emperor Leto II ha...  1981-05-28 00:00:00

# %%
book_data.loc[ymd_idx, 'pub_date_cleaned'] = pd.to_datetime(book_data.loc[ymd_idx, 'pub_date'], format = "%Y-%m-%d")

# %%
book_data.loc[year_only_idx, 'pub_date_cleaned'] = pd.to_datetime(book_data.loc[year_only_idx, 'pub_date'], format = "%Y", errors = "coerce")

# %%
book_data.loc[year_month_idx, 'pub_date_cleaned'] = pd.to_datetime(book_data.loc[year_month_idx, 'pub_date'], format = "%Y-%m", errors = "coerce")

# %%
book_data.loc[~book_data['pub_date_cleaned'].isna()]
# Out:
#         wiki_id freebase_id  \
# 0           620     /m/0hhy
# 1           843     /m/0k36
# 2           986     /m/0ldx
# 5          2152     /m/0x5g
# 6          2890    /m/011zx
# ...         ...         ...
# 16554  36934824  /m/0m0p0hr
# 16555  37054020  /m/04f1nbs
# 16556  37122323  /m/0n5236t
# 16557  37132319  /m/0n4bqb1
# 16558  37159503   /m/073nkd
#
#                                                    title  \
# 0                                            Animal Farm
# 1                                     A Clockwork Orange
# 2                                             The Plague
# 5                         All Quiet on the Western Front
# 6                                   A Wizard of Earthsea
# ...                                                  ...
# 16554                                     Under Wildwood
# 16555                                  Transfer of Power
# 16556                                            Decoded
# 16557  America Again: Re-becoming The Greatness We Ne...
# 16558                                          Poor Folk
#
#                      author    pub_date  \
# 0             George Orwell  1945-08-17
# 1           Anthony Burgess        1962
# 2              Albert Camus        1947
# 5      Erich Maria Remarque  1929-01-29
# 6         Ursula K. Le Guin        1968
# ...                     ...         ...
# 16554           Colin Meloy  2012-09-25
# 16555           Vince Flynn  2000-06-01
# 16556                 Jay-Z  2010-11-16
# 16557       Stephen Colbert  2012-10-02
# 16558    Fyodor Dostoyevsky        1846
#
#                                                   genres  \
# 0      {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1      {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2      {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 5      {"/m/098tmk": "War novel", "/m/016lj8": "Roman...
# 6      {"/m/0dwly": "Children's literature", "/m/01hm...
# ...                                                  ...
# 16554
# 16555   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16556                       {"/m/0xdf": "Autobiography"}
# 16557
# 16558  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                summaries     pub_date_cleaned
# 0       Old Major, the old boar on the Manor Farm, ca...  1945-08-17 00:00:00
# 1       Alex, a teenager living in near-future Englan...  1962-01-01 00:00:00
# 2       The text of The Plague is divided into five p...  1947-01-01 00:00:00
# 5       The book tells the story of Paul Bäumer, a Ge...  1929-01-29 00:00:00
# 6       Ged is a young boy on Gont, one of the larger...  1968-01-01 00:00:00
# ...                                                  ...                  ...
# 16554   Prue McKeel, having rescued her brother from ...  2012-09-25 00:00:00
# 16555   The reader first meets Rapp while he is doing...  2000-06-01 00:00:00
# 16556   The book follows very rough chronological ord...  2010-11-16 00:00:00
# 16557   Colbert addresses topics including Wall Stree...  2012-10-02 00:00:00
# 16558   Makar Devushkin and Varvara Dobroselova are s...  1846-01-01 00:00:00
#
# [10901 rows x 8 columns]

# %%
book_data_ts = book_data.loc[~book_data['pub_date_cleaned'].isna()]
book_data_ts['pub_date_cleaned'] = pd.to_datetime(book_data_ts['pub_date_cleaned'])
book_data_ts['pub_date_year'] = book_data_ts['pub_date_cleaned'].dt.year
# Out:
# C:\Users\smont\Anaconda3\envs\msba\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\smont\Anaconda3\envs\msba\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
books_yearly = book_data_ts.groupby('pub_date_year')['wiki_id'].count()

# %%
plt.plot(books_yearly)
plt.show()

# %%
genre_lookup = dict()
genre_to_book_dict = defaultdict(list)
book_to_genre_dict = defaultdict(list)
for idx, g in enumerate(book_data['genres']):
    try:
        g_json = json.loads(g)
    except:
        if g != "":
            print(idx)
            print(g)
            print(book_data.iloc[idx,])
            break
    genre_lookup.update(g_json)
